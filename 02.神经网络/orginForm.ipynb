# %%
import numpy as np
import matplotlib.pylab as plt

# %%
def stepFun(x):
    y = x > 0
    return y.astype(int)

x = np.arange(-0.5,0.5,0.01)
y = stepFun(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
def sigmaoid(x):
    return 1/(1+np.exp(-x))

x = np.arange(-10,10,0.01)
y = sigmaoid(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
def reLU(x):
    return np.maximum(0,x)

x = np.arange(-0.5,0.5,0.01)
y = reLU(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
def identity_function(x):
    return x

# %%
def softmax(x):
    c = np.max(x)
    e=np.exp(x-c)
    return e/np.sum(e)

# %%
def forward_netWork(input,layers,weights,bias,stim_mid,stim_fin):
    #input为输入行向量，类型为np.array；layers为网络层数；weights为网络权重，为由二维矩阵构成的元组；
    #bias为网络偏移，为由一维向量构成的元组；stim_mid为中间激活函数；stim_fin为最后一层到输出层的激活函数
    for i in range(layers-1) :
        tmp = np.dot(input,weights[i])+bias[i]
        input = stim_mid(tmp)
    tmp = np.dot(input,weights[layers-1])+bias[layers-1]
    return stim_fin(tmp)

# %%
x = np.array([1.0, 0.5])
layers=3
weights1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
weights2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
weights3 = np.array([[0.1, 0.3], [0.2, 0.4]])
weights=(weights1,weights2,weights3)
bias1 = np.array([0.1, 0.2, 0.3])
bias2 = np.array([0.1, 0.2])
bias3 = np.array([0.1, 0.2])
bias=(bias1,bias2,bias3)
y = forward_netWork(x,layers,weights,bias,sigmaoid,identity_function)
y
# Out:
# array([0.31682708, 0.69627909])
